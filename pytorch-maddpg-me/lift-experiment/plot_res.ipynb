# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
dir1 = "ag3height10"
pg1 = np.load(dir1+"/pg_ag3h10.npy")
ma1 = np.load(dir1+"/maddpgrw_ag3h10.npy")
marule1 = np.load(dir1+"/ma_ag3h10r1.npy")

# %%
print(len(pg1))
print(len(ma1))
print(len(marule1))
# Out:
# 1476
# 100
# 80

# %%
arr1 = []
for i in range(int((1476-6)/35)):
    ind = int((i*35)+6)
    arr1.append(pg1[ind])

# %%
arr2 = []
for i in range(int(100/3)):
    ind = int(((i+1)*3))
    arr2.append(ma1[ind])

# %%
arr3 = []
for i in range(int(80/2)):
    ind = int((i)*2)
    arr3.append(marule1[ind])

# %%
plt.plot(range(len(arr1)),arr1)
plt.plot(range(len(arr2)),arr2)
plt.plot(range(len(arr3)),arr3)

# %%
dir1 = "ag5height10"
pg1 = np.load(dir1+"/pg_ag3h10.npy")
ma1 = np.load(dir1+"/maddpgrw_ag3h10.npy")
marule1 = np.load(dir1+"/ma_ag3h10r1.npy")
