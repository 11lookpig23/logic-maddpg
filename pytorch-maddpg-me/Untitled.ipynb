# %%
import numpy as np
maddpgrw = np.load("maddpgrw.npy")
maddpgrw
# Out:
# array([-0.50875, -0.48375, -0.49   , -0.4975 , -0.545  , -0.4975 ,
#        -0.51375, -0.51125, -0.48875, -0.50125, -0.47625, -0.4675 ,
#        -0.47125, -0.51   , -0.5125 , -0.51625, -0.5175 , -0.5125 ,
#        -0.45375, -0.38   , -0.335  , -0.21875, -0.2625 , -0.2125 ,
#        -0.2675 , -0.19625, -0.17625, -0.1875 , -0.1475 , -0.15   ,
#        -0.155  , -0.1275 , -0.14125, -0.15375, -0.13125, -0.1125 ,
#        -0.1325 , -0.1675 , -0.1075 , -0.1775 , -0.135  , -0.1575 ,
#        -0.16125, -0.115  , -0.12625, -0.10125, -0.1425 , -0.135  ,
#        -0.1325 , -0.1175 , -0.1475 , -0.18   , -0.13625, -0.15375,
#        -0.17625, -0.14   , -0.115  , -0.12   , -0.12625, -0.12125,
#        -0.16   , -0.13875, -0.17   , -0.1825 , -0.12   , -0.14   ,
#        -0.1225 , -0.1425 , -0.1475 , -0.145  , -0.15625, -0.1125 ,
#        -0.15375, -0.135  , -0.1225 , -0.12875, -0.17125, -0.1275 ,
#        -0.1525 , -0.14125, -0.1475 , -0.1225 , -0.12625, -0.1775 ,
# ...

# %%
len(maddpgrw)
sum(maddpgrw[-20:])/20
# Out:
# -0.14318749867379665

# %%
import matplotlib.pyplot as plt
rt = [-0.48097500000000004, -0.472925, -0.4323374999999999, -0.4304000000000003, -0.39296249999999994, -0.37846250000000015, -0.39446250000000005, -0.40622500000000017, -0.40722499999999995, -0.41305000000000014, -0.43514999999999987, -0.4499375, -0.4589625, -0.46574999999999994, -0.46645000000000003, -0.46934999999999993, -0.46884999999999993, -0.47452500000000014, -0.47758749999999983, -0.4784000000000001, -0.48052500000000015, -0.4641125000000001, -0.47638749999999996, -0.4881250000000002, -0.4788375000000001, -0.487725, -0.4810500000000003, -0.4820749999999998, -0.4795125]

plt.plot(range(len(rt)),rt)
plt.savefig("pgrw.png")
plt.show()
